# %%
import json
import requests

# %% [markdown]
# Only if you're using your environmental variable eith the `.env` file, import/install the following modules. Otherwise it is not necessary:
#
# https://pypi.org/project/python-dotenv/

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# %% [markdown]
# # Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is ironhack-datalabs/datamad1020-rev, you will:
#
# 1. Obtain the full list of forks created from the main lab repo via Github API.
#
# 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
#
# Hint: Each language should appear only once in your array.
#
# 3. Print the language array. It should be something like:
#
# ["Python", "Jupyter Notebook", "HTML"]

# %% [markdown]
# **HINT:**: Create a list with every **language_url** you find in every fork

# %% [markdown]
# ⚠️ **Remember to limit your output before submission**.

# %%
url_1 = "https://api.github.com/repos/Ironhack-Data-Madrid-Mayo-2021/Classroom-Materials/forks"

# %%
response_1 = requests.get(url_1)

# %%
response_1.status_code
# Out:
# 200

# %%
forks = response_1.json()

# %%
forks
# Out:
# [{'id': 377518052,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNzc1MTgwNTI=',
#   'name': 'Classroom-Materials',
#   'full_name': 'Santimo89/Classroom-Materials',
#   'private': False,
#   'owner': {'login': 'Santimo89',
#    'id': 62174153,
#    'node_id': 'MDQ6VXNlcjYyMTc0MTUz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62174153?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Santimo89',
#    'html_url': 'https://github.com/Santimo89',
#    'followers_url': 'https://api.github.com/users/Santimo89/followers',
#    'following_url': 'https://api.github.com/users/Santimo89/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Santimo89/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Santimo89/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Santimo89/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Santimo89/orgs',
# ...

# %%
len(forks)
# Out:
# 6

# %%
forks[5]["languages_url"]
# Out:
# 'https://api.github.com/repos/alvarogb1919/Classroom-Materials/languages'

# %%
fork_languages = []

# %%
url_languages = [l["languages_url"] for l in forks]

# %%
all_languages = []
for link in url_languages:
    res = requests.get(link).json()
    all_languages.append(res)

# %%
all_languages
# Out:
# [{'Jupyter Notebook': 6648803},
#  {'Jupyter Notebook': 6430952},
#  {'Jupyter Notebook': 317092},
#  {'Jupyter Notebook': 109955},
#  {'Jupyter Notebook': 787055},
#  {'Jupyter Notebook': 6648803}]

# %%
language_list = [language for element in all_languages for language in element.keys()]

# %%
language_list
# Out:
# ['Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook',
#  'Jupyter Notebook']

# %%
final = set(language_list)

# %%
list(final)
# Out:
# ['Jupyter Notebook']
